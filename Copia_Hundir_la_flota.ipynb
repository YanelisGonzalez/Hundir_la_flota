# %%
import random
import numpy as np

# %%
# Crear Tableros

def crear_tablero(tamagno=10):
    
    return np.full((tamagno, tamagno), "__")

mi_tablero = crear_tablero()
pc_tablero = crear_tablero()

print("Mi Tablero")
print(mi_tablero)
print("PC Tablero")
print(pc_tablero)
# Out:
# Mi Tablero
# [['__' '__' '__' '__' '__' '__' '__' '__' '__' '__']
#  ['__' '__' '__' '__' '__' '__' '__' '__' '__' '__']
#  ['__' '__' '__' '__' '__' '__' '__' '__' '__' '__']
#  ['__' '__' '__' '__' '__' '__' '__' '__' '__' '__']
#  ['__' '__' '__' '__' '__' '__' '__' '__' '__' '__']
#  ['__' '__' '__' '__' '__' '__' '__' '__' '__' '__']
#  ['__' '__' '__' '__' '__' '__' '__' '__' '__' '__']
#  ['__' '__' '__' '__' '__' '__' '__' '__' '__' '__']
#  ['__' '__' '__' '__' '__' '__' '__' '__' '__' '__']
#  ['__' '__' '__' '__' '__' '__' '__' '__' '__' '__']]
# PC Tablero
# [['__' '__' '__' '__' '__' '__' '__' '__' '__' '__']
#  ['__' '__' '__' '__' '__' '__' '__' '__' '__' '__']
#  ['__' '__' '__' '__' '__' '__' '__' '__' '__' '__']
#  ['__' '__' '__' '__' '__' '__' '__' '__' '__' '__']
#  ['__' '__' '__' '__' '__' '__' '__' '__' '__' '__']
#  ['__' '__' '__' '__' '__' '__' '__' '__' '__' '__']
#  ['__' '__' '__' '__' '__' '__' '__' '__' '__' '__']
#  ['__' '__' '__' '__' '__' '__' '__' '__' '__' '__']
#  ['__' '__' '__' '__' '__' '__' '__' '__' '__' '__']
#  ['__' '__' '__' '__' '__' '__' '__' '__' '__' '__']]

# %%
# Crear Mi Tablero vacío

def crear_tablero(filas, columnas):
    return [["-" for _ in range(columnas)] for _ in range(filas)]

# Colocar Mis barcos en  Mi Tablero

def colocar_barcos(lista_barcos, tablero):
    for barco in lista_barcos:
        for fila, columna in barco:
            if 0 <= fila < len(tablero) and 0 <= columna < len(tablero[0]):
                if tablero[fila][columna] == "-":
                    tablero[fila][columna] = "O"
                else:
                    raise ValueError(f"La posición ({fila}, {columna}) ya está ocupada.")
            else:
                raise ValueError(f"La posición ({fila}, {columna}) está fuera del tablero.")

# Imprimir Tablero con los barcos posicionados

def imprimir_tablero(tablero):
    for fila in tablero:
        print(" ".join(fila))
    print()

# Variable Tablero de 10x10

tablero = crear_tablero(10, 10)

# Listas de Mis barcos

barco_1 = [(0, 1), (1, 1)]     
barco_2 = [(1, 3), (1, 4), (1, 5), (1, 6)]  
barco_3 = [(4, 8), (5, 8)]  
barco_4 = [(7, 3), (8, 3)]  
barco_5 = [(4, 5), (5, 5), (6, 5)]  
barco_6 = [(6, 0), (7, 0), (8, 0)]

# Coloca todos los barcos en el tablero

barcos = [barco_1, barco_2, barco_3, barco_4, barco_5, barco_6]

try:
    colocar_barcos(barcos, tablero)
except ValueError as e:
    print(f"Error al colocar los barcos: {e}")

print("Mi Tablero")

# Imprimir el tablero después de colocar los barcos

imprimir_tablero(tablero)
# Out:
# Mi Tablero
# - O - - - - - - - -
# - O - O O O O - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - O - - O -
# - - - - - O - - O -
# O - - - - O - - - -
# O - - O - - - - - -
# O - - O - - - - - -
# - - - - - - - - - -

# %%
# Crear PC Tablero vacío

def crear_tablero(filas, columnas):
    return [["-" for _ in range(columnas)] for _ in range(filas)]

# Colocar PC barcos en  PC Tablero

def colocar_barcos(lista_barcos, tablero):
    for barco in lista_barcos:
        for fila, columna in barco:
            if 0 <= fila < len(tablero) and 0 <= columna < len(tablero[0]):
                if tablero[fila][columna] == "-":
                    tablero[fila][columna] = "O"
                else:
                    raise ValueError(f"La posición ({fila}, {columna}) ya está ocupada.")
            else:
                raise ValueError(f"La posición ({fila}, {columna}) está fuera del tablero.")

# Imprimir Tablero con los barcos posicionados

def imprimir_tablero(tablero):
    for fila in tablero:
        print(" ".join(fila))
    print()

# Variable Tablero de 10x10

tablero = crear_tablero(10, 10)

# Listas de PC barcos

barco_1 = [(0, 3), (0, 4)]    # 2 eslora
barco_2 = [(2, 6), (2, 7), (2, 8), (2, 9)] # 4 eslora
barco_3 = [(2 ,3), (3, 3)] # 2 eslora
barco_4 = [(7, 6), (8, 6)] # 2 eslora
barco_5 = [(9, 0), (9, 1), (9, 2)] # 3eslora
barco_6 = [(9,5), (9, 6), (9, 7)] # 3 eslora

# Coloca todos los barcos en el tablero

barcos = [barco_1, barco_2, barco_3, barco_4, barco_5, barco_6]

try:
    colocar_barcos(barcos, tablero)
except ValueError as e:
     print(f"Error al colocar los barcos: {e}")

print("PC Tablero")

# Imprimir el tablero después de colocar los barcos

imprimir_tablero(tablero)
# Out:
# PC Tablero
# - - - O O - - - - -
# - - - - - - - - - -
# - - - O - - O O O O
# - - - O - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - O - - -
# - - - - - - O - - -
# O O O - - O O O - -

# %%
# Disparar

def disparar(casilla, tablero):

    fila, columna = casilla
    if tablero[fila][columna] == 'O':  
        tablero[fila][columna] = 'X'
        print("¡Tocado!")
    elif tablero[fila][columna] == '_': 
        tablero[fila][columna] = 'A'
        print("Agua")
    else:  # Ya disparado
        print("Ya disparaste aquí.")
    
    return tablero


# Tablero de prueba: 'O' para barcos, '_' para agua

tablero = [
    ['_', '_', '_', '_', '_', "_","_", "_", "_", "_"],
    ['_', 'O', 'O', '_', '_', "_","_", "_", "_", "_"],
    ['_', '_', '_', '_', '_', "_","_", "_", "_", "_"],
    ['_', '_', '_', '_', '_', "_","_", "_", "_", "_"],
    ['_', '_', '_', '_', '_', "_","_", "_", "_", "_"]
]



# Disparos de prueba

print("Tablero inicial:")
for fila in tablero:
    print(' '.join(fila))

# Prueba con disparos
disparar((1, 1), tablero)  # Tocado
disparar((1, 2), tablero)  # Tocado
disparar((0, 0), tablero)  # Agua
disparar((1, 1), tablero)  # Repetido

print("\nTablero actualizado:")
for fila in tablero:
    print(' '.join(fila))
# Out:
# Tablero inicial:
# _ _ _ _ _ _ _ _ _ _
# _ O O _ _ _ _ _ _ _
# _ _ _ _ _ _ _ _ _ _
# _ _ _ _ _ _ _ _ _ _
# _ _ _ _ _ _ _ _ _ _
# ¡Tocado!
# ¡Tocado!
# Agua
# Ya disparaste aquí.
#
# Tablero actualizado:
# A _ _ _ _ _ _ _ _ _
# _ X X _ _ _ _ _ _ _
# _ _ _ _ _ _ _ _ _ _
# _ _ _ _ _ _ _ _ _ _
# _ _ _ _ _ _ _ _ _ _

# %%
def crear_barco(eslora, tam_tablero=10):

    orientacion = random.choice(['horizontal', 'vertical'])  # Orientación del barco
    if orientacion == 'horizontal':
        fila = random.randint(0, tam_tablero - 1)
        columna_inicial = random.randint(0, tam_tablero - eslora)
        return [(fila, columna_inicial + i) for i in range(eslora)]
    else:  # orientacion == 'vertical'
        columna = random.randint(0, tam_tablero - 1)
        fila_inicial = random.randint(0, tam_tablero - eslora)
        return [(fila_inicial + i, columna) for i in range(eslora)]

# Ejemplo de uso

eslora = 2
barco = crear_barco(eslora)
print("Coordenadas del barco:", barco)
# Out:
# Coordenadas del barco: [(1, 4), (2, 4)]
